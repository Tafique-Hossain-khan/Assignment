# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of
# Matplotlib.

# %% [markdown]
# Matplotlib is a python library that is helpfull for reading the insites form the data in the form of graphs

# %%
df=pd.read_csv('student.csv')

# %%
df=df.iloc[:10]

# %%
df
# Out:
#    id         name  class  mark  gender
# 0   1     John Deo   Four    75  female
# 1   2     Max Ruin  Three    85    male
# 2   3       Arnold  Three    55    male
# 3   4   Krish Star   Four    60  female
# 4   5    John Mike   Four    60  female
# 5   6    Alex John   Four    55    male
# 6   7  My John Rob  Fifth    78    male
# 7   8       Asruid   Five    85    male
# 8   9      Tes Qry    Six    78    male
# 9  10     Big John   Four    55  female

# %%
plt.scatter(x=df.mark,y=df.id)

# %%
areas= np.array(['Marketing','sales','Devlopment','HR','Customer Suppoert'])
budged = np.array([2,4,10,1,6])

# %%
plt.pie(budged,labels=areas, autopct="%0.1f%%")
plt.show()

# %%
product_id=[1,2,3,4,5]
ofline_price=[200,300,250,459,100]
online_price=[150,153,670,72,360]
chore_bazar_price=[200,150,100,120,200]

# %%
plt.plot(product_id,ofline_price,marker="+",markersize=10,label='ofline_price')
plt.xlabel('poduct')
plt.ylabel("price")
plt.title("Product Details")
plt.plot(product_id,online_price,marker="+",markersize=10,label='online price')
plt.plot(product_id,chore_bazar_price,marker="+",markersize=10,label ='chore_bazar_price')
plt.legend()
plt.show()

# %%
years=[2012,2014,2016,2018,2020]
bick_price=[65000,69000,75000,55000,80000]

# %%
plt.bar(years,bick_price)
plt.xlabel('years')
plt.ylabel('bick_price')
plt.title('Prces of bick')

plt.show()

# %%
data = [1,1,2,3,3,3,4,4,4,4,5,6,6,7,8,8,8,8,8,8,8]

# %%
plt.hist(data)
plt.xlabel('data')
plt.ylabel('data count')
plt.grid()

# %% [markdown]
# Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data
# plot a scatter plot.

# %%
np.random.seed(3)

x = 3 + np.random.normal(0, 2, 50)

y = 3 + np.random.normal(0, 2, len(x))

# %%
#scatter plot it a graph in which data is displayed in scatterd form

plt.scatter(x=y,y=x)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title("scatter graph")
# Out:
# Text(0.5, 1.0, 'scatter graph')

# %%
plt.subplot()

# %%
years=[2012,2014,2016,2018,2020]
bick_price=[65000,69000,75000,55000,80000]
plt.bar(years,bick_price)
plt.xlabel('years')
plt.ylabel('bick_price')
plt.title('Prces of bick')

plt.show()

# %%
x = np.array([0, 1, 2, 3, 4, 5]) 
y = np.array([0, 100, 200, 300, 400, 500])
plt.subplot(3,2,1)
plt.bar(x,y)

#data2
x = np.array([0, 1, 2, 3, 4, 5]) 
y = np.array([50, 20, 40, 20, 60, 70])
plt.subplot(3,2,2)
plt.bar(x,y)

#data3
x = np.array([0, 1, 2, 3, 4, 5]) 
y = np.array([10, 20, 30, 40, 50, 60])
plt.subplot(3,2,3)
plt.bar(x,y)


#data4
x = np.array([0, 1, 2, 3, 4, 5]) 
y = np.array([200, 350, 250, 550, 450, 150])
plt.subplot(3,2,4)
plt.scatter(x,y)

# %% [markdown]
# Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot

# %%
#Bar charts should be used when you are showing segments of information.

company = np.array(["Apple", "Microsoft", "Google", "AMD"])

profit = np.array([3000, 8000, 1000, 10000])

# %%
plt.bar(company,profit)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.barh(company,profit)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# Q5: What is a box plot? Why is it used? Using the following data plot a box plot.

# %%
box1 = np.random.normal(100, 10, 200)

box2 = np.random.normal(90, 20, 200)

# %%
dataset=[box1,box2]

# %%
plt.boxplot(dataset)
plt.show()
